# %% [markdown]
# # Introduction to Ray for Distributed Computing in Python
#
# ## Overview
#
# Ray is an open-source framework for scaling Python applications. It provides a simple, universal API for building distributed applications. Ray is particularly useful in machine learning and artificial intelligence workflows, where it can help parallelize computations and manage distributed resources efficiently.
#
# In this lecture, we'll cover:
#
# 1. Basic Ray concepts
# 2. Setting up Ray
# 3. Remote functions and parallel execution
# 4. Ray Tasks vs. Actors
# 5. Shared memory and object stores
# 6. Ray for Machine Learning
# 7. Best practices and considerations
#
# Let's begin by installing Ray and importing necessary libraries.

# %%
# !pip install ray

import ray
import numpy as np
import time
# Out:
# Collecting ray
#   Downloading ray-2.49.2-cp313-cp313-macosx_12_0_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/lib/python3.13/site-packages (from ray) (8.3.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from ray) (3.17.0)
# Requirement already satisfied: jsonschema in /opt/anaconda3/lib/python3.13/site-packages (from ray) (4.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from ray) (1.0.3)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from ray) (25.0)
# Requirement already satisfied: protobuf>=3.20.3 in /opt/anaconda3/lib/python3.13/site-packages (from ray) (6.33.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.13/site-packages (from ray) (6.0.3)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from ray) (2.32.5)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema->ray) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema->ray) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema->ray) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema->ray) (0.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->ray) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->ray) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests->ray) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->ray) (2025.10.5)
# Downloading ray-2.49.2-cp313-cp313-macosx_12_0_x86_64.whl (69.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 MB 1.5 MB/s eta 0:00:0000:0100:020m
# Installing collected packages: ray
# Successfully installed ray-2.49.2

# %% [markdown]
# ## 1. Basic Ray Concepts
#
# Ray's core abstraction is a task - a remote function invocation. Ray uses these tasks to distribute computation across a cluster of machines. The key components of Ray are:
#
# - **Workers**: Python processes that execute tasks.
# - **Drivers**: The main Python script that defines and invokes remote tasks.
# - **Object Store**: A distributed shared-memory object store.
# - **Scheduler**: Assigns tasks to workers.
#
# ## 2. Setting up Ray
#
# To use Ray, we first need to initialize it. This can be done locally or on a cluster.

# %%
# Initialize Ray
ray.init()

# You can also specify resources
# ray.init(num_cpus=4, num_gpus=1)
# Out:
# 2025-11-06 23:40:38,301	INFO worker.py:1951 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.13.5', ray_version='2.49.2', ray_commit='479fa716904109d9df4b56b98ca3c3350e1ec13c')

# %% [markdown]
# ## 3. Remote Functions and Parallel Execution
#
# Ray allows you to execute functions remotely using the `@ray.remote` decorator. These functions can run in parallel on different machines or cores.

# %%
@ray.remote
def slow_function(i):
    time.sleep(1)  # Simulate a slow operation
    return i * i

# Execute functions in parallel
start_time = time.time()
results = ray.get([slow_function.remote(i) for i in range(4)])
end_time = time.time()

print(f"Results: {results}")
print(f"Time taken: {end_time - start_time:.2f} seconds")
# Out:
# Results: [0, 1, 4, 9]
# Time taken: 2.74 seconds

# %% [markdown]
# In this example, we define a `slow_function` that simulates a time-consuming operation. By using `@ray.remote`, we can execute multiple instances of this function in parallel, significantly reducing the total execution time.
#
# ## 4. Ray Tasks vs. Actors
#
# Ray provides two main abstractions for parallel computation:
#
# 1. **Tasks**: Stateless functions (like we saw above)
# 2. **Actors**: Stateful workers
#
# Let's look at an example using an Actor:

# %%
@ray.remote
class Counter:
    def __init__(self):
        self.value = 0
    
    def increment(self):
        self.value += 1
        return self.value

# Create an actor
counter = Counter.remote()

# Increment the counter in parallel
results = ray.get([counter.increment.remote() for _ in range(5)])
print(f"Counter values: {results}")
# Out:
# Counter values: [1, 2, 3, 4, 5]

# %% [markdown]
# In this example, we create a `Counter` actor that maintains its state across method calls. This is useful for scenarios where you need to maintain state in a distributed setting.
#
# ## 5. Shared Memory and Object Stores
#
# Ray uses a distributed object store to efficiently pass large objects between tasks. This is particularly useful for machine learning workloads with large datasets or models.

# %%
# Create a large object
large_matrix = np.random.rand(1000, 1000)

# Put the object in the object store
matrix_id = ray.put(large_matrix)

@ray.remote
def matrix_sum(matrix):
    return np.sum(matrix)

# Use the object reference in a task
result = ray.get(matrix_sum.remote(matrix_id))
print(f"Sum of matrix elements: {result}")
# Out:
# Sum of matrix elements: 499805.733176693

# %% [markdown]
# By using `ray.put()`, we can efficiently share large objects between tasks without the need for serialization and deserialization.
#
# ## 6. Ray for Machine Learning
#
# Ray provides several libraries specifically designed for machine learning workloads:
#
# - **Ray Tune**: For hyperparameter tuning
# - **Ray Train**: For distributed model training
# - **Ray Serve**: For model serving
#
# Let's look at a simple example using Ray Tune for hyperparameter optimization:

# %%
# !pip install "ray[tune]"
from ray import tune
from ray.tune.schedulers import ASHAScheduler

def objective(config):
    # Simulate a model training process
    for step in range(100):
        intermediate_score = config["a"] * step + config["b"]
        tune.report(score=intermediate_score)

analysis = tune.run(
    objective,
    config={
        "a": tune.uniform(0, 1),
        "b": tune.uniform(0, 20)
    },
    num_samples=10,
    scheduler=ASHAScheduler(metric="score", mode="max")
)

print("Best config:", analysis.get_best_config(metric="score", mode="max"))
# Out:
# Requirement already satisfied: ray[tune] in /opt/anaconda3/lib/python3.13/site-packages (2.49.2)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (8.3.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (3.17.0)
# Requirement already satisfied: jsonschema in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (4.25.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (1.0.3)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (25.0)
# Requirement already satisfied: protobuf>=3.20.3 in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (6.33.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (6.0.3)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (2.32.5)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (2.3.3)
# Requirement already satisfied: tensorboardX>=1.9 in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (2.6.4)
# Requirement already satisfied: pyarrow>=9.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (21.0.0)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.13/site-packages (from ray[tune]) (2025.3.2)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from tensorboardX>=1.9->ray[tune]) (2.3.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema->ray[tune]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema->ray[tune]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema->ray[tune]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema->ray[tune]) (0.27.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas->ray[tune]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas->ray[tune]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas->ray[tune]) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->ray[tune]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->ray[tune]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->ray[tune]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests->ray[tune]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->ray[tune]) (2025.10.5)
# 2025-11-06 23:54:01,618	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-11-06 23:54:09</td></tr>
# <tr><td>Running for: </td><td>00:00:08.12        </td></tr>
# <tr><td>Memory:      </td><td>9.7/16.0 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=0<br>Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None<br>Logical resource usage: 1.0/12 CPUs, 0/0 GPUs
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 10<br><table>
# <thead>
# <tr><th>Trial name           </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                             </th></tr>
# </thead>
# <tbody>
# <tr><td>objective_ec937_00000</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-11-06_23-40-32_600001_83504/artifacts/2025-11-06_23-54-01/objective_2025-11-06_23-54-01/driver_artifacts/objective_ec937_00000_0_a=0.4604,b=19.2130_2025-11-06_23-54-01/error.txt</td></tr>
# <tr><td>objective_ec937_00001</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-11-06_23-40-32_600001_83504/artifacts/2025-11-06_23-54-01/objective_2025-11-06_23-54-01/driver_artifacts/objective_ec937_00001_1_a=0.3571,b=0.8988_2025-11-06_23-54-01/error.txt </td></tr>
# <tr><td>objective_ec937_00002</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-11-06_23-40-32_600001_83504/artifacts/2025-11-06_23-54-01/objective_2025-11-06_23-54-01/driver_artifacts/objective_ec937_00002_2_a=0.9475,b=19.9041_2025-11-06_23-54-01/error.txt</td></tr>
# <tr><td>objective_ec937_00003</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-11-06_23-40-32_600001_83504/artifacts/2025-11-06_23-54-01/objective_2025-11-06_23-54-01/driver_artifacts/objective_ec937_00003_3_a=0.4321,b=2.9179_2025-11-06_23-54-01/error.txt </td></tr>
# <tr><td>objective_ec937_00004</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-11-06_23-40-32_600001_83504/artifacts/2025-11-06_23-54-01/objective_2025-11-06_23-54-01/driver_artifacts/objective_ec937_00004_4_a=0.5417,b=4.8485_2025-11-06_23-54-01/error.txt </td></tr>
# <tr><td>objective_ec937_00005</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-11-06_23-40-32_600001_83504/artifacts/2025-11-06_23-54-01/objective_2025-11-06_23-54-01/driver_artifacts/objective_ec937_00005_5_a=0.3978,b=4.6048_2025-11-06_23-54-01/error.txt </td></tr>
# <tr><td>objective_ec937_00006</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-11-06_23-40-32_600001_83504/artifacts/2025-11-06_23-54-01/objective_2025-11-06_23-54-01/driver_artifacts/objective_ec937_00006_6_a=0.3052,b=18.0832_2025-11-06_23-54-01/error.txt</td></tr>
# <tr><td>objective_ec937_00007</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-11-06_23-40-32_600001_83504/artifacts/2025-11-06_23-54-01/objective_2025-11-06_23-54-01/driver_artifacts/objective_ec937_00007_7_a=0.5360,b=9.0804_2025-11-06_23-54-01/error.txt </td></tr>
# <tr><td>objective_ec937_00008</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-11-06_23-40-32_600001_83504/artifacts/2025-11-06_23-54-01/objective_2025-11-06_23-54-01/driver_artifacts/objective_ec937_00008_8_a=0.9083,b=19.5289_2025-11-06_23-54-01/error.txt</td></tr>
# <tr><td>objective_ec937_00009</td><td style="text-align: right;">           1</td><td>/tmp/ray/session_2025-11-06_23-40-32_600001_83504/artifacts/2025-11-06_23-54-01/objective_2025-11-06_23-54-01/driver_artifacts/objective_ec937_00009_9_a=0.8138,b=17.3183_2025-11-06_23-54-01/error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc            </th><th style="text-align: right;">       a</th><th style="text-align: right;">        b</th></tr>
# </thead>
# <tbody>
# <tr><td>objective_ec937_00000</td><td>ERROR   </td><td>127.0.0.1:83865</td><td style="text-align: right;">0.460372</td><td style="text-align: right;">19.213   </td></tr>
# <tr><td>objective_ec937_00001</td><td>ERROR   </td><td>127.0.0.1:83861</td><td style="text-align: right;">0.357126</td><td style="text-align: right;"> 0.898774</td></tr>
# <tr><td>objective_ec937_00002</td><td>ERROR   </td><td>127.0.0.1:83864</td><td style="text-align: right;">0.94748 </td><td style="text-align: right;">19.9041  </td></tr>
# <tr><td>objective_ec937_00003</td><td>ERROR   </td><td>127.0.0.1:83862</td><td style="text-align: right;">0.432089</td><td style="text-align: right;"> 2.91793 </td></tr>
# <tr><td>objective_ec937_00004</td><td>ERROR   </td><td>127.0.0.1:83863</td><td style="text-align: right;">0.541685</td><td style="text-align: right;"> 4.84846 </td></tr>
# <tr><td>objective_ec937_00005</td><td>ERROR   </td><td>127.0.0.1:83868</td><td style="text-align: right;">0.397818</td><td style="text-align: right;"> 4.60475 </td></tr>
# <tr><td>objective_ec937_00006</td><td>ERROR   </td><td>127.0.0.1:83866</td><td style="text-align: right;">0.305158</td><td style="text-align: right;">18.0832  </td></tr>
# <tr><td>objective_ec937_00007</td><td>ERROR   </td><td>127.0.0.1:83867</td><td style="text-align: right;">0.536022</td><td style="text-align: right;"> 9.08036 </td></tr>
# <tr><td>objective_ec937_00008</td><td>ERROR   </td><td>127.0.0.1:83869</td><td style="text-align: right;">0.908304</td><td style="text-align: right;">19.5289  </td></tr>
# <tr><td>objective_ec937_00009</td><td>ERROR   </td><td>127.0.0.1:83870</td><td style="text-align: right;">0.81379 </td><td style="text-align: right;">17.3183  </td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2025-11-06 23:54:08,569	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_ec937_00005
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2882, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 968, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=83868, ip=127.0.0.1, actor_id=ab3c03754e8ab1067ad41deb01000000, repr=objective)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/var/folders/84/_3s4n8jj2sd32bzwhbbh9j6r0000gq/T/ipykernel_83504/1345816351.py", line 9, in objective
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/train/_internal/session.py", line 663, in wrapper
#     return fn(*args, **kwargs)
# TypeError: report() got an unexpected keyword argument 'score'
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name           </th></tr>
# </thead>
# <tbody>
# <tr><td>objective_ec937_00000</td></tr>
# <tr><td>objective_ec937_00001</td></tr>
# <tr><td>objective_ec937_00002</td></tr>
# <tr><td>objective_ec937_00003</td></tr>
# <tr><td>objective_ec937_00004</td></tr>
# <tr><td>objective_ec937_00005</td></tr>
# <tr><td>objective_ec937_00006</td></tr>
# <tr><td>objective_ec937_00007</td></tr>
# <tr><td>objective_ec937_00008</td></tr>
# <tr><td>objective_ec937_00009</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# 2025-11-06 23:54:08,623	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_ec937_00004
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2882, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 968, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=83863, ip=127.0.0.1, actor_id=3e7fa342e51595bf3b7a889701000000, repr=objective)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/var/folders/84/_3s4n8jj2sd32bzwhbbh9j6r0000gq/T/ipykernel_83504/1345816351.py", line 9, in objective
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/train/_internal/session.py", line 663, in wrapper
#     return fn(*args, **kwargs)
# TypeError: report() got an unexpected keyword argument 'score'
# 2025-11-06 23:54:08,681	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_ec937_00008
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2882, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 968, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=83869, ip=127.0.0.1, actor_id=14c84e5cc92778b5ead4623901000000, repr=objective)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/var/folders/84/_3s4n8jj2sd32bzwhbbh9j6r0000gq/T/ipykernel_83504/1345816351.py", line 9, in objective
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/train/_internal/session.py", line 663, in wrapper
#     return fn(*args, **kwargs)
# TypeError: report() got an unexpected keyword argument 'score'
# 2025-11-06 23:54:08,716	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_ec937_00001
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2882, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 968, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=83861, ip=127.0.0.1, actor_id=d7806cbb08aa7c1415ad0ba701000000, repr=objective)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/var/folders/84/_3s4n8jj2sd32bzwhbbh9j6r0000gq/T/ipykernel_83504/1345816351.py", line 9, in objective
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/train/_internal/session.py", line 663, in wrapper
#     return fn(*args, **kwargs)
# TypeError: report() got an unexpected keyword argument 'score'
# 2025-11-06 23:54:08,749	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_ec937_00006
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2882, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 968, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=83866, ip=127.0.0.1, actor_id=88a9e12e6f110b85a76de47201000000, repr=objective)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/var/folders/84/_3s4n8jj2sd32bzwhbbh9j6r0000gq/T/ipykernel_83504/1345816351.py", line 9, in objective
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/train/_internal/session.py", line 663, in wrapper
#     return fn(*args, **kwargs)
# TypeError: report() got an unexpected keyword argument 'score'
# 2025-11-06 23:54:08,834	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_ec937_00007
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2882, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 968, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=83867, ip=127.0.0.1, actor_id=34adbba1504adb9c8421f48c01000000, repr=objective)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/var/folders/84/_3s4n8jj2sd32bzwhbbh9j6r0000gq/T/ipykernel_83504/1345816351.py", line 9, in objective
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/train/_internal/session.py", line 663, in wrapper
#     return fn(*args, **kwargs)
# TypeError: report() got an unexpected keyword argument 'score'
# 2025-11-06 23:54:08,895	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_ec937_00000
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2882, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 968, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=83865, ip=127.0.0.1, actor_id=5efc74116e3c95ab412a735601000000, repr=objective)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/var/folders/84/_3s4n8jj2sd32bzwhbbh9j6r0000gq/T/ipykernel_83504/1345816351.py", line 9, in objective
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/train/_internal/session.py", line 663, in wrapper
#     return fn(*args, **kwargs)
# TypeError: report() got an unexpected keyword argument 'score'
# 2025-11-06 23:54:08,929	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_ec937_00002
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2882, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 968, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=83864, ip=127.0.0.1, actor_id=fc88d7a22ff7109fb4a4eb7b01000000, repr=objective)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/var/folders/84/_3s4n8jj2sd32bzwhbbh9j6r0000gq/T/ipykernel_83504/1345816351.py", line 9, in objective
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/train/_internal/session.py", line 663, in wrapper
#     return fn(*args, **kwargs)
# TypeError: report() got an unexpected keyword argument 'score'
# 2025-11-06 23:54:09,012	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_ec937_00003
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2882, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 968, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=83862, ip=127.0.0.1, actor_id=6533fb9e3840ffabc264680701000000, repr=objective)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/var/folders/84/_3s4n8jj2sd32bzwhbbh9j6r0000gq/T/ipykernel_83504/1345816351.py", line 9, in objective
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/train/_internal/session.py", line 663, in wrapper
#     return fn(*args, **kwargs)
# TypeError: report() got an unexpected keyword argument 'score'
# 2025-11-06 23:54:09,709	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_ec937_00009
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/client_mode_hook.py", line 104, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 2882, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/_private/worker.py", line 968, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::ImplicitFunc.train() (pid=83870, ip=127.0.0.1, actor_id=2cadc83cfc91840fd1c6411101000000, repr=objective)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/air/_internal/util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/tune/trainable/function_trainable.py", line 261, in _trainable_func
#     output = fn()
#   File "/var/folders/84/_3s4n8jj2sd32bzwhbbh9j6r0000gq/T/ipykernel_83504/1345816351.py", line 9, in objective
#   File "/opt/anaconda3/lib/python3.13/site-packages/ray/train/_internal/session.py", line 663, in wrapper
#     return fn(*args, **kwargs)
# TypeError: report() got an unexpected keyword argument 'score'
# 2025-11-06 23:54:09,750	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/dvalia/ray_results/objective_2025-11-06_23-54-01' in 0.0257s.
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       8         intermediate_score = config["a"] * step + config["b"]
#       9         tune.report(score=intermediate_score)
# ---> 11 analysis = tune.run(
#      12     objective,
#      13     config={
#      14         "a": tune.uniform(0, 1),
#      15         "b": tune.uniform(0, 20)
#      16     },
#      17     num_samples=10,
#      18     scheduler=ASHAScheduler(metric="score", mode="max")
#      19 )
#      21 print("Best config:", analysis.get_best_config(metric="score", mode="max"))
#
# File /opt/anaconda3/lib/python3.13/site-packages/ray/tune/tune.py:1035, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, resume, resume_config, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _remote, _remote_string_queue, _entrypoint)
#    1033 if incomplete_trials:
#    1034     if raise_on_failed_trial and not experiment_interrupted_event.is_set():
# -> 1035         raise TuneError("Trials did not complete", incomplete_trials)
#    1036     else:
#    1037         logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [objective_ec937_00000, objective_ec937_00001, objective_ec937_00002, objective_ec937_00003, objective_ec937_00004, objective_ec937_00005, objective_ec937_00006, objective_ec937_00007, objective_ec937_00008, objective_ec937_00009])

# %% [markdown]
# This example demonstrates how Ray Tune can be used to optimize hyperparameters in a distributed manner.
#
# ## 7. Best Practices and Considerations
#
# When using Ray, keep the following best practices in mind:
#
# 1. **Task Granularity**: Ensure tasks are not too small (overhead of distribution) or too large (limits parallelism).
# 2. **Resource Management**: Specify CPU and GPU requirements for tasks and actors when necessary.
# 3. **Error Handling**: Use Ray's built-in retry mechanisms for fault tolerance.
# 4. **Monitoring**: Utilize Ray's dashboard for cluster monitoring and debugging.
# 5. **Data Transfer**: Minimize data transfer between nodes by using Ray's object store effectively.
#
# ## Conclusion
#
# Ray provides a powerful framework for distributed computing in Python, with particular strengths in machine learning workflows. Its simple API allows for easy parallelization of existing code, while its specialized libraries offer advanced functionality for ML tasks.
#
# In an MLOps context, Ray can be particularly useful for:
# - Distributed data preprocessing
# - Parallel model training
# - Hyperparameter tuning at scale
# - Distributed inference
#
# By integrating Ray into your MLOps pipeline, you can significantly improve the scalability and efficiency of your machine learning workflows.
